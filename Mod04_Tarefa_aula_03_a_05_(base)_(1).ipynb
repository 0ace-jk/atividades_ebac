# %% [markdown]
# <a href="https://colab.research.google.com/github/0ace-jk/atividades_ebac/blob/main/Mod04_Tarefa_aula_03_a_05_(base)_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Exercício 1: Vestibular
#
# Considere que a os dados gerados na célula abaixo contêm o número de acertos de 100 alunos em um vestibular para um curso de exatas, divididas pelos respectivos assuntos. Considere que cada assunto possui um número de questões conforme a tabela abaixo:
#
# | assunto | número de questões |
# |:---:|:---:|
# | Matemática | 24 |
# | Português | 18 |
# | Geografia | 8 |
# | Inglês | 8 |
# | História | 8 |
# | Física | 12 |
# | Química | 12 |
#
# Usando os comandos de operações com DataFrames que você aprendeu na Aula 03, calcule:
#
# 1. (operações com escalar) Calcule o percentual de acerto dos alunos por assunto.
# 2. (operações entre *DataFrames) Calcule o total de acertos de cada aluno.
# 3. Calcule o porcentual geral de cada aluno.
# 4. Suponha que a nota de corte para a segunda fase seja 45. Quantos alunos tiveram nota maior que 45?

# %%
import pandas as pd
import numpy as np

np.random.seed(42)
df_mat = pd.DataFrame(np.random.randint(24, size=(100, 1)), columns=['Qt_acertos'])

df_por = pd.DataFrame(np.random.randint(18, size=(100, 1)), columns=['Qt_acertos'])

df_geo = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_ing = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_his = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_fis = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos'])

df_qui = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos'])

# %%
# 1) Seu código aqui

# Acertos Matematica
percentual_mat = df_mat['Qt_acertos'].sum() / len(df_mat) / 24
print(f'Os alunos acertam {(percentual_mat * 100).round(2)}% das questões de Matematica')
# Acertos Portugues
percentual_por = df_por['Qt_acertos'].sum() / len(df_por) / 18
print(f'Os alunos acertam {(percentual_por * 100).round(2)}% das questões de Portugues')
# Acertos Geografia
percentual_geo = df_geo['Qt_acertos'].sum() / len(df_geo) / 8
print(f'Os alunos acertam {(percentual_geo * 100).round(2)}% das questões de Geografia')
# Acertos Ingles
percentual_ing = df_ing['Qt_acertos'].sum() / len(df_ing) / 8
print(f'Os alunos acertam {(percentual_ing * 100).round(2)}% das questões de Ingles')
# Acertos Historia
percentual_his = df_his['Qt_acertos'].sum() / len(df_his) / 8
print(f'Os alunos acertam {(percentual_his * 100).round(2)}% das questões de Historia')
# Acertos Fisica
percentual_fis = df_fis['Qt_acertos'].sum() / len(df_fis) / 12
print(f'Os alunos acertam {(percentual_fis * 100).round(2)}% das questões de Fisica')
# Acertos Quimica
percentual_qui = df_qui['Qt_acertos'].sum() / len(df_qui) / 12
print(f'Os alunos acertam {(percentual_qui * 100).round(2)}% das questões de Quimica')
# Out:
# Os alunos acertam 49.38% das questões de Matematica
# Os alunos acertam 40.17% das questões de Portugues
# Os alunos acertam 42.0% das questões de Geografia
# Os alunos acertam 47.62% das questões de Ingles
# Os alunos acertam 45.0% das questões de Historia
# Os alunos acertam 44.33% das questões de Fisica
# Os alunos acertam 45.25% das questões de Quimica

# %%
# aqui eu crio Data Frames específicos para cada matéria
df_mat_alunos = df_mat.rename(columns={'Qt_acertos': 'Qt_acertos_mat'})
df_por_alunos = df_por.rename(columns={'Qt_acertos': 'Qt_acertos_por'})
df_geo_alunos = df_geo.rename(columns={'Qt_acertos': 'Qt_acertos_geo'})
df_ing_alunos = df_ing.rename(columns={'Qt_acertos': 'Qt_acertos_ing'})
df_his_alunos = df_his.rename(columns={'Qt_acertos': 'Qt_acertos_his'})
df_fis_alunos = df_fis.rename(columns={'Qt_acertos': 'Qt_acertos_fis'})
df_qui_alunos = df_qui.rename(columns={'Qt_acertos': 'Qt_acertos_qui'})
df_alunos = pd.DataFrame(np.arange(1, 101),columns = ['id_aluno'])

# %%
# neste codigo eu concateno os dataframes das materias para um unico dataframe
# e ja indexo a coluna id_alunos
alunos = [df_alunos,
          df_mat_alunos,
          df_por_alunos,
          df_geo_alunos,
          df_ing_alunos,
          df_his_alunos,
          df_fis_alunos,
          df_qui_alunos]
df_resultado = pd.concat(alunos, axis=1)
df_resultado.set_index('id_aluno', inplace = True)

# %%
# 2) Seu código aqui

df_resultado['Qt_acertos_total'] = df_resultado.loc[:,'Qt_acertos_mat':].sum(axis=1)
df_resultado['Qt_acertos_total']
# Out:
# id_aluno
# 1      35
# 2      48
# 3      50
# 4      32
# 5      30
#        ..
# 96     34
# 97     27
# 98     40
# 99     40
# 100    42
# Name: Qt_acertos_total, Length: 100, dtype: int64

# %%
# 3) Seu código aqui

df_resultado['percentual_acertos'] = df_resultado['Qt_acertos_total'] / 90
df_resultado['percentual_acertos']
# Out:
# id_aluno
# 1      0.388889
# 2      0.533333
# 3      0.555556
# 4      0.355556
# 5      0.333333
#          ...
# 96     0.377778
# 97     0.300000
# 98     0.444444
# 99     0.444444
# 100    0.466667
# Name: percentual_acertos, Length: 100, dtype: float64

# %%
# 4) Seu código aqui

df_resultado['aluno_aprovado'] = df_resultado['percentual_acertos'] > 0.45
print(f"A quantidade de alunos aprovados foi de {df_resultado['aluno_aprovado'].sum()} alunos")
# Out:
# A quantidade de alunos aprovados foi de 47 alunos

# %% [markdown]
# ## 2) Vestibular II
#
# Ainda sobre o mesmo banco de dados:
#
# 1. Neste vestibular, quem 'zera' em matemática, física ou química está desqualificado. Monte um novo *DataFrame* com os alunos desqualificados por este critério.
# 2. Quantos são esses alunos?
# 3. Qual a média desses alunos em história e geografia?
# 4. Monte um *DataFrame* com os alunos que passaram para a segunda fase. Repare que estes alunos não podem ter sido desqualificados.

# %%
# 1) seu código aqui

df_resultado['aprovado_mat'] = df_resultado['Qt_acertos_mat'] != 0
df_resultado['aprovado_fis'] = df_resultado['Qt_acertos_fis'] != 0
df_resultado['aprovado_qui'] = df_resultado['Qt_acertos_qui'] != 0
df_resultado['aluno_aprovado'] = df_resultado['aprovado_mat'] & df_resultado['aprovado_fis'] & df_resultado['aprovado_qui']
df_reprovados = df_resultado.loc[df_resultado['aluno_aprovado'] == False]
df_reprovados.head(5)
# Out:
#           Qt_acertos_mat  Qt_acertos_por  Qt_acertos_geo  Qt_acertos_ing  \
# id_aluno
# 4                     10               7               3               4
# 7                      6               0               7               7
# 11                    10               8               3               2
# 13                    20               8               3               7
# 15                     7              11               1               7
#
#           Qt_acertos_his  Qt_acertos_fis  Qt_acertos_qui  Qt_acertos_total  \
# id_aluno
# 4                      0               0               8                32
# 7                      5               0               4                29
# 11                     1               7               0                31
# 13                     1               0               3                42
# 15                     1               4               0                31
#
# ...

# %%
# 2) seu código aqui

print(f'A quantidade de alunos reprovados é de {df_reprovados.shape[0]} alunos')
# Out:
# A quantidade de alunos reprovados é de 23 alunos

# %%
# 3) seu código aqui

print(f"A média de acertos em historia desses alunos é de {df_reprovados['Qt_acertos_his'].mean().round(2)} questões")
print(f"A média de acertos em geografia desses alunos é de {df_reprovados['Qt_acertos_geo'].mean().round(2)} questões")
# Out:
# A média de acertos em historia desses alunos é de 3.43 questões
# A média de acertos em geografia desses alunos é de 3.22 questões

# %%
# 4) seu código aqui

df_aprovados = df_resultado.loc[df_resultado['aluno_aprovado'] == True]
print(f'Aprovados: {df_aprovados.shape[0]} alunos')
df_aprovados.head(5)
# Out:
# Aprovados: 77 alunos
#           Qt_acertos_mat  Qt_acertos_por  Qt_acertos_geo  Qt_acertos_ing  \
# id_aluno
# 1                      6               7               7               3
# 2                     19              10               0               0
# 3                     14              16               0               5
# 5                      7               2               2               7
# 6                     20               2               5               3
#
#           Qt_acertos_his  Qt_acertos_fis  Qt_acertos_qui  Qt_acertos_total  \
# id_aluno
# 1                      1               8               3                35
# 2                      0              11               8                48
# 3                      7               4               4                50
# 5                      0               9               3                30
# 6                      2               9               9                50
#
# ...

# %% [markdown]
# ## 3) Vacinações no Acre
# Vamos trabalhar agora com a base de vacinações no Acre. Para facilitar a sua vida, copiamos o link do arquivo na célula abaixo.
#
# 1. Quantas vacinas estão registradas nessa base?
# 2. Quantos pacientes foram vacinados? (considere um paciente para cada valor único de ```paciente_id```)
# 3. Quantos pacientes únicos tomaram a primeira dose? OBS: Há um caractere especial neste campo. Receba os valores do campo com o método ```.unique()```.
# 4. Quantos pacientes com menos de 18 anos foram vacinados?
# 5. Quantos estabelecimentos aplicaram vacina no Acre?
#
#
# **OBS:** O portal do DATASUS pode apresentar instabilidades, retornando um erro na segunda célula abaixo. Por este motivo está disponível uma base estática, que se for baixada para o seu *working directory* pode ser lida com este comando: ```df = pd.read_csv('registros de vacinacao covid ACRE.csv', sep=';')```.
#
# **OBS2:** Para saber qual é o seu working directory, rode no jupyter: ```!pwd```.

# %%
arquivo = '/content/csv/registros de vacinacao covid ACRE.csv'

# %%
df = pd.read_csv(arquivo, sep=';')

# %%
# aqui eu identifico as colunas e seus tipos no dataframe
df.dtypes
# Out:
# document_id                                  object
# paciente_id                                  object
# paciente_idade                                int64
# paciente_datanascimento                      object
# paciente_enumsexobiologico                   object
# paciente_racacor_codigo                       int64
# paciente_racacor_valor                       object
# paciente_endereco_coibgemunicipio           float64
# paciente_endereco_copais                    float64
# paciente_endereco_nmmunicipio                object
# paciente_endereco_nmpais                     object
# paciente_endereco_uf                         object
# paciente_endereco_cep                       float64
# paciente_nacionalidade_enumnacionalidade     object
# estabelecimento_valor                         int64
# estabelecimento_razaosocial                  object
# estalecimento_nofantasia                     object
# estabelecimento_municipio_codigo              int64
# ...

# %%
# Nesse codigo eu observo a quantidade de linhas que o df possui, isso pode ser util
df.shape
# Out:
# (169071, 34)

# %%
# extremamente importante para observar a construção e os dados que esse df possui
df.head(5)
# Out:
#                                  document_id  \
# 0  b19cd280-474c-4c22-a35d-8c06bc04a4e0-i0b0
# 1  a1acc0b6-1cf6-4c4b-adcb-06b473a0faaf-i0b0
# 2  af279a98-ba1f-47ea-8214-314a98040b0d-i0b0
# 3  4879308e-5050-46bb-b8e2-11fa5646a05c-i0b0
# 4  000e911b-e3a4-4114-a735-d1f2e6e3797f-i0b0
#
#                                          paciente_id  paciente_idade  \
# 0  2e091c9a37d3f50d1d705fc80c6448c6fc69b44da9e936...              69
# 1  f4e17a9e5354cb45e223d85eda02fb2f76048c801675f5...              81
# 2  6734b26bccf826130ebffa66575977bbe71477b12bcf42...              69
# 3  84a341fd350c1ba7117fccbb4d2df417bc0fac0fffac37...              51
# 4  c59571e19f368d4b0cf08cd3bcabb32e5cd8baad5340f6...              65
#
#   paciente_datanascimento paciente_enumsexobiologico  paciente_racacor_codigo  \
# 0              1951-12-28                          F                        3
# 1              1939-11-22                          M                        3
# ...

# %%
# 1) Sua solução aqui

# aqui atividade eu posso buscar as vacinas pelo seu codigo ou pelo seu nome
# Caso eu queira os codigos das vacinas: df['vacina_codigo'].unique()
# Caso eu queira os nomes das vacinasdf['vacina_nome'].unique()
print(f"Temos um total de {df['vacina_codigo'].nunique()} diferentes vacinas")
# Out:
# Temos um total de 5 diferentes vacinas

# %%
# 2)

# utilizando o mesmo atributo do codigo anterior
# df['paciente_id'].nunique()
print(f"Temos um total de {df['paciente_id'].nunique()} pacientes unicos")
# Out:
# Temos um total de 120517 pacientes unicos

# %%
# 3) solução alternativa

# aqui eu limpo o df em um novo dataframe com somente a coluna da descrição da dose da vacina

# df_dose = df['vacina_descricao_dose']
df['vacina_descricao_dose'].unique()
df_dose = df['vacina_descricao_dose'].str.replace('\xa0', '').str.replace('ª', '')
print(f"Um total de {df_dose.value_counts()['1Dose']} vacinas foram aplicadas como primeira dose")
# Out:
# Um total de 120939 vacinas foram aplicadas como primeira dose

# %%
# 3)

# aqui eu faço a contagem das vacinas pegando sua descrição atravéz do atributo .unique()

# df['vacina_descricao_dose'].value_counts()['\xa0\xa0\xa0\xa01ª\xa0Dose']
contagem = df['vacina_descricao_dose'].value_counts()['\xa0\xa0\xa0\xa01ª\xa0Dose']
print(f'Um total de {contagem} vacinas foram aplicadas como primeira dose')
# Out:
# Um total de 120939 vacinas foram aplicadas como primeira dose

# %%
# 4)

idade_menor = df[df['paciente_idade'] < 18]['paciente_idade'].shape[0]
print(f'Um total de {idade_menor} pacientes com menos de 18 anos foram vacinados')
# Out:
# Um total de 55 pacientes com menos de 18 anos foram vacinados

# %%
# 5)
print(f"Um total de {df['estalecimento_nofantasia'].nunique()} estabelecimentos aplicaram a vacina")
# Out:
# Um total de 103 estabelecimentos aplicaram a vacina

# %% [markdown]
# ## 4) Vacinação II
# Gere um *DataFrame* que contenha somente os estabelecimentos que aplicaram vcinas a menores de 18 anos. Nesse *DataFrame* devem conter somente os dados dos estabelecimentos, mais uma coluna sendo a quantidade de vacinas que o estabelecimento aplicou a menores de 18 anos.
#
# 1. crie uma cópia do *DataFrame* original, contendo somente os registros de vacinas realizadas a menores de 18 anos.
# 2. crie uma lista das colunas desse *DataFrame* com o atributo de *DataFrame* **.columns()**
# 3. Nesse *DataFrame* faça uma contagem do campo ```vacina_categoria_nome```.
# 3. a partir da lista de colunas, escolha somente aquelas que são referentes ao estabelecimento, faça uma lista com esses valores.
# 4. usando o método *.loc*, selecione somente essas variáveis
# 5. Aplique o método **.drop_duplicates** e crie uma lista com uma linha para cada estabelecimento, com os dados do estabelecimento

# %%
df_estabelecimentos = df[df['paciente_idade'] < 18]['estalecimento_nofantasia'].value_counts()
df_estabelecimentos
# Out:
# estalecimento_nofantasia
# POLO BASE DE MARECHAL THAUMATURGO                              9
# UBS VICENTE VARELA DE ALMEIDA                                  8
# POLO BASE DE FEIJO                                             6
# DEPARTAMENTO DE VIGILANCIA EPIDEMIOLOGICA E AMBIENTAL          4
# POLO BASE INDIGENA                                             4
# POLO BASE DE ASSIS BRASIL                                      3
# SECRETARIA MUNICIPAL DE SAUDE DE CRUZEIRO DO SUL               3
# CENTRO DE SAUDE DIAMANTINO MACEDO                              3
# POLO BASE DE MANCIO LIMA                                       3
# POLO BASE DE PORTO WALTER                                      2
# UNIDADE ASSISTENCIAL A SAUDE INDIGENA DE TARAUACA POLO BASE    2
# POLO INDIGENA DE MANOEL URBANO                                 2
# DISTRITO SANITARIO ESPECIAL INDIGENA ALTO PURUS                1
# UNIDADE DE SAUDE DA FAMILIA ALVARO ARAUJO NOBRE                1
# ...

# %%
# 1)

df_menor = df[df['paciente_idade'] < 18]
df_menor.head(5)
# Out:
#                                      document_id  \
# 1567   fdca313f-b348-422d-94d4-f2c66a87868c-i0b0
# 6250   b7431955-1faa-4c1e-9246-7c1e7b8bb3cb-i0b0
# 9569   fdb8d3b6-14d9-4bcc-9cfe-acd46b4a317a-i0b0
# 11338  647e2301-3ba4-463a-8d1e-2b6f38a4d99e-i0b0
# 15144  7f469e03-bece-49d0-bebc-33ad98e27f54-i0b0
#
#                                              paciente_id  paciente_idade  \
# 1567   f5e6b8c44f7c4d13a87c582def5e8d460435b02f26af8c...              17
# 6250   e1a45c07e3c393d5f0eccf4204a7ceab338f4f06696ecb...              16
# 9569   7cf3b238383a70eeb26841c01817737c9706d5b231e8c2...              17
# 11338  53eb7fed5faa26ad17ce21ee378f28e25399ab7e90bc05...              17
# 15144  dbaa6420d8a815158387668d0a59a19cf2bb63958e35d1...              16
#
#       paciente_datanascimento paciente_enumsexobiologico  \
# 1567               2003-07-18                          F
# 6250               2004-05-18                          M
# ...

# %%
# 2)

df_menor.columns
# Out:
# Index(['document_id', 'paciente_id', 'paciente_idade',
#        'paciente_datanascimento', 'paciente_enumsexobiologico',
#        'paciente_racacor_codigo', 'paciente_racacor_valor',
#        'paciente_endereco_coibgemunicipio', 'paciente_endereco_copais',
#        'paciente_endereco_nmmunicipio', 'paciente_endereco_nmpais',
#        'paciente_endereco_uf', 'paciente_endereco_cep',
#        'paciente_nacionalidade_enumnacionalidade', 'estabelecimento_valor',
#        'estabelecimento_razaosocial', 'estalecimento_nofantasia',
#        'estabelecimento_municipio_codigo', 'estabelecimento_municipio_nome',
#        'estabelecimento_uf', 'vacina_grupoatendimento_codigo',
#        'vacina_grupoatendimento_nome', 'vacina_categoria_codigo',
#        'vacina_categoria_nome', 'vacina_lote', 'vacina_fabricante_nome',
#        'vacina_fabricante_referencia', 'vacina_dataaplicacao',
#        'vacina_descricao_dose', 'vacina_codigo', 'vacina_nome',
# ...

# %%
# 3)

df_menor['vacina_categoria_nome'].value_counts()
# Out:
# vacina_categoria_nome
# Povos Indígenas                     33
# Trabalhadores de Saúde               9
# Povos e Comunidades Tradicionais     9
# Comorbidades                         2
# Faixa Etária                         1
# Name: count, dtype: int64

# %%
# 4)

df_menor.columns[14:20]
# Out:
# Index(['estabelecimento_valor', 'estabelecimento_razaosocial',
#        'estalecimento_nofantasia', 'estabelecimento_municipio_codigo',
#        'estabelecimento_municipio_nome', 'estabelecimento_uf'],
#       dtype='object')

# %%
# 5)

df_menor.loc[:, df_menor.columns[14:20]].head(5)
# Out:
#        estabelecimento_valor  \
# 1567                 2001314
# 6250                 6917291
# 9569                 6159087
# 11338                2000040
# 15144                7625855
#
#                              estabelecimento_razaosocial  \
# 1567              PREFEITURA MUNICIPAL DE EPITACIOLANDIA
# 6250                  PREFEITURA MUNICIPAL DE RIO BRANCO
# 9569             PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL
# 11338                      PREFEITURA MUNICIPAL DE FEIJO
# 15144  DISTRITO SANITARIO ESPECIAL INDIGENA ALTO RIO ...
#
#                                 estalecimento_nofantasia  \
# 1567                             ESF JOAO ALVES DA SILVA
# 6250   DEPARTAMENTO DE VIGILANCIA EPIDEMIOLOGICA E AM...
# 9569    SECRETARIA MUNICIPAL DE SAUDE DE CRUZEIRO DO SUL
# 11338                  CENTRO DE SAUDE DIAMANTINO MACEDO
# 15144                  POLO BASE DE MARECHAL THAUMATURGO
#
#        estabelecimento_municipio_codigo estabelecimento_municipio_nome  \
# ...

# %%
# 6)

df_menor.loc[:, df_menor.columns[14:20]].drop_duplicates(subset = ['estalecimento_nofantasia'])
# Out:
#         estabelecimento_valor  \
# 1567                  2001314
# 6250                  6917291
# 9569                  6159087
# 11338                 2000040
# 15144                 7625855
# 17153                 6748759
# 18361                 6308740
# 18608                 2001748
# 20204                 6917682
# 21119                 6428940
# 29127                 6612385
# 57405                 9648968
# 61131                 6430201
# 68290                 6955525
# 69882                 5336171
# 70881                 6697151
# 101402                3323307
# 140895                7123043
#
#                               estabelecimento_razaosocial  \
# 1567               PREFEITURA MUNICIPAL DE EPITACIOLANDIA
# 6250                   PREFEITURA MUNICIPAL DE RIO BRANCO
# 9569              PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL
# 11338                       PREFEITURA MUNICIPAL DE FEIJO
# 15144   DISTRITO SANITARIO ESPECIAL INDIGENA ALTO RIO ...
# ...

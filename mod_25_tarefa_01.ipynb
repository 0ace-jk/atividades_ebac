# %% [markdown]
# # Cálculo - Tarefa 01
#
# 1. Marque quais desses métodos/algoritmos muito populares em ciência de dados são baseados no uso de derivada:
#
#     1. Método Mínimos Quadrados
#     2. Gradiente descendente
#     3. Newton Raphson
#     4. CART (Árvore de decisão)

# %% [markdown]
# ---
#
# - Método dos Mínimos Quadrados(SIM) - usa derivadas para encontrar o ponto mínimo da função de custo.
# - Gradiente Descendente(SIM) - é um algoritmo de otimização que utiliza derivadas para minimizar funções.
# - Newton Raphson(SIM) - é um método iterativo que usa derivadas para encontrar raízes de funções.
# - CART (Árvore de Decisão)(NÃO) - não utiliza derivadas, pois é baseado em divisões recursivas dos dados.
#
# ---

# %% [markdown]
# 2. Dada uma base de dados com uma variável resposta $y$ e um conjunto de variáveis explicativas. Considere uma estrutura de um modelo de regressão. Explique com suas palavras por que não é possível obter parâmetros que forneçam um erro quadrático médio (EQM) menor que o obtido com estimadores de mínimos quadrados.

# %% [markdown]
# ---
#
# - A resposta está na própria definição do método. Não é possível obter um Erro Quadrático Médio (EQM) menor porque o método de Mínimos Quadrados (MQ) é, por construção, o procedimento matemático que encontra os únicos parâmetros que minimizam essa métrica.
# - Portanto, qualquer outro conjunto de parâmetros resultaria em um EQM maior ou igual ao obtido pelos estimadores de MQ.
#
# ---
